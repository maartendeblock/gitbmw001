# %% [markdown]
# # Import relevant libraries

# %%
# Import relevant Python packages, for instance:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# # Load curated datasets

# %%
# Read in .pkl files of curated datasets from "../CURATED/DATA".
# Please DO NOT use absolute paths in your Python scripts (!).
# Filter out the data needed for the descriptive analysis, if needed.

# %% [markdown]
# # Perform descriptive analysis

# %%
# Extract various graphs and key figures from the data, without doing serious statistical modelling.
