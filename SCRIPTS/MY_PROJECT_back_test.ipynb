# %% [markdown]
# # Import relevant libraries

# %%
# Import relevant Python libraries, for instance:

import pickle
import pandas as pd
import numpy as np
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Our own utilities_be package contains a lot of useful functions for building predictive models using Python.
# If you want to import it here, then you should first clone it under the SCRIPTS folder.
import utilities_be.predictive_be as ub

# %% [markdown]
# # Import curated datasets

# %%
# Read in .pkl files of curated datasets from "../CURATED/DATA".
# Please DO NOT use absolute paths in your Python scripts (!).
# Filter out the data needed for the descriptive analysis, if needed.

# %% [markdown]
# # Import predictive model

# %%
# Load the calibrated model in .pkl format from "../RESULTS".
# Please DO NOT use absolute paths in your Python scripts (!).

# %% [markdown]
# # Back test predictive model

# %%
# Apply predictive model on curated data on the appropriate part of the available data history. 
# Compare observed outcomes with predicted outcomes.
