# %% [markdown]
# # Import relevant libraries

# %%
# Import Python libraries here, for instance:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
import datetime

# %% [markdown]
# # Load raw datasets

# %%
# Import raw data sets here from "../RAW_DATA"
# After importing them, save them again under "../RAW_DATA" in .pkl format such that you can import them much faster in the future
# Please DO NOT put absolute paths in your scripts (!).

# %% [markdown]
# # Data cleansing

# %%
# Preprocessing of your raw data: 
# renaming variables, removing or clipping outliers, deleting a handful of observations with very poor data quality, etc.

# %% [markdown]
# # Save curated datasets

# %%
# Save curated datasets under "../CURATED_DATA".
# Please DO NOT put absolute paths in your scripts (!).
